# %% [markdown]
# <a href="https://colab.research.google.com/github/daylightzjr/daylightzjr/blob/main/clip_simple_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cn_clip

# %%
import torch
import cn_clip.clip as clip
from cn_clip.clip import load_from_name,available_models
from PIL import Image
print("Available Model:",available_models())
device = "cuda" if torch.cuda.is_available() else "cpu"
model,preprocessor = load_from_name("ViT-B-16",device=device)
model.eval()
image = preprocessor(Image.open("./image_1.jpg")).unsqueeze(0).to(device)
labels =["一辆车","房子","车行驶在公路上","车往开到房子","这是一张图片"]
text = clip.tokenize(labels).to(device)
# Out:
# Available Model: ['ViT-B-16', 'ViT-L-14', 'ViT-L-14-336', 'ViT-H-14', 'RN50']
# Loading vision model config from /usr/local/lib/python3.11/dist-packages/cn_clip/clip/model_configs/ViT-B-16.json
# Loading text model config from /usr/local/lib/python3.11/dist-packages/cn_clip/clip/model_configs/RoBERTa-wwm-ext-base-chinese.json
# Model info {'embed_dim': 512, 'image_resolution': 224, 'vision_layers': 12, 'vision_width': 768, 'vision_patch_size': 16, 'vocab_size': 21128, 'text_attention_probs_dropout_prob': 0.1, 'text_hidden_act': 'gelu', 'text_hidden_dropout_prob': 0.1, 'text_hidden_size': 768, 'text_initializer_range': 0.02, 'text_intermediate_size': 3072, 'text_max_position_embeddings': 512, 'text_num_attention_heads': 12, 'text_num_hidden_layers': 12, 'text_type_vocab_size': 2}

# %%
print(image.shape)
# Out:
# torch.Size([1, 3, 224, 224])

# %%
print(text.shape)
# Out:
# torch.Size([5, 52])

# %%
with torch.no_grad():
  logits_per_image,logits_per_text = model.get_similarity(image,text)
  probs = logits_per_image.softmax(dim=1).cpu().numpy()
print(probs)
# Out:
# [[8.690e-03 2.043e-04 9.434e-01 4.276e-02 5.108e-03]]
